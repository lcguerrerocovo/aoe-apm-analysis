# %%
import sys
sys.path.append('..')

from bokeh.io import output_notebook
output_notebook()

import importlib
import utils.viz
import utils.aoe_rec
importlib.reload(utils.viz)
importlib.reload(utils.aoe_rec)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ea4cf9e4-1eea-4bbd-8319-94c07e32916c">Loading BokehJS ...</span>
#     </div>
# <module 'utils.aoe_rec' from '/Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py'>

# %%
from utils.aoe_rec import prepare_rec
from utils.viz import plot_apm

plot_apm(prepare_rec('./data/latest.aoe2record'))
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:78: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#           player relative_minute          type  count
# 0  <NT>.tornasol               0         BUILD      2
# 1  <NT>.tornasol               0      DE_QUEUE      4
# 2  <NT>.tornasol               0  GATHER_POINT      4
# 3  <NT>.tornasol               0          MOVE     89
# 4  <NT>.tornasol               0         ORDER      5
#   <div id="a83bfb98-6026-408e-80b0-2c04f1f67b28" data-root-id="p10084" style="display: contents;"></div>
#     player relative_minute          type  count
# 272  BigAl               0         BUILD      2
# 273  BigAl               0      DE_QUEUE      4
# 274  BigAl               0  GATHER_POINT      2
# 275  BigAl               0          MOVE     33
# 276  BigAl               0         ORDER      5
# ...

# %%
import pandas as pd
from IPython.display import display, Markdown
from utils.aoe_rec import ACTION_TYPE_DESCRIPTIONS

desc_table = pd.DataFrame([
    {"Action": k, "Description": v}
    for k, v in ACTION_TYPE_DESCRIPTIONS.items()
])
display(Markdown(desc_table.to_markdown(index=False)))
# Out:
# | Action                | Description                                                                                      |
# |:----------------------|:-------------------------------------------------------------------------------------------------|
# | ERROR                 | Error or unknown action.                                                                         |
# | ORDER                 | Generic order issued to a unit (e.g., patrol, guard, gather, attack-move).                       |
# | STOP                  | Orders a unit to halt its current action.                                                        |
# | WORK                  | Villager or unit performs a work action (e.g., gather, build, repair).                           |
# | MOVE                  | Orders a unit to move to a location.                                                             |
# ...

# %%
plot_apm(prepare_rec('./data/theviper.aoe2record'))
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:78: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#     player relative_minute          type  count
# 0  GL.DauT               0         BUILD      2
# 1  GL.DauT               0      DE_QUEUE      3
# 2  GL.DauT               0  GATHER_POINT      4
# 3  GL.DauT               0          MOVE     43
# 4  GL.DauT               0         ORDER      9
#   <div id="fba7c548-8724-48e7-881d-dfecc8de7e55" data-root-id="p10644" style="display: contents;"></div>
#           player relative_minute          type  count
# 184  GL.TheViper               0         BUILD      1
# 185  GL.TheViper               0      DE_QUEUE      4
# 186  GL.TheViper               0  GATHER_POINT      4
# 187  GL.TheViper               0          MOVE     53
# 188  GL.TheViper               0         ORDER     12
# ...

# %%
from utils.aoe_rec import rec_to_df
df = rec_to_df('./data/theviper.aoe2record')
df.head()
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:100: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(jsonFile)
#            type                                            payload   player  \
# 0          GAME  {'command_id': 16, 'sequence': 416, 'command':...  GL.DauT
# 1          GAME  {'command_id': 19, 'sequence': 416, 'command':...  GL.DauT
# 2  DE_TRANSFORM            {'object_ids': [1650], 'sequence': 416}  GL.DauT
# 3  DE_TRANSFORM            {'object_ids': [1650], 'sequence': 416}  GL.DauT
# 4  DE_TRANSFORM            {'object_ids': [1650], 'sequence': 416}  GL.DauT
#
#   position  relative_minute
# 0      NaN                0
# 1      NaN                0
# 2      NaN                0
# 3      NaN                0
# 4      NaN                0

# %%
filtered = df[
    (df['player'] == 'GL.TheViper') &
    (df['relative_minute'].astype(float).astype(int) == 19)
]
filtered.head()
# Out:
#               type                                            payload  \
# 3197  GATHER_POINT  {'target_id': -1, 'target_type': -1, 'object_i...
# 3198  GATHER_POINT  {'target_id': -1, 'target_type': -1, 'object_i...
# 3199     FORMATION  {'formation_id': 2, 'object_ids': [6540, 6538,...
# 3200     FORMATION  {'formation_id': 2, 'object_ids': [6540, 6538,...
# 3201     FORMATION  {'formation_id': 2, 'object_ids': [6540, 6538,...
#
#            player                                          position  \
# 3197  GL.TheViper  {'x': 30.14583396911621, 'y': 46.22916793823242}
# 3198  GL.TheViper           {'x': 30.23958396911621, 'y': 46.03125}
# 3199  GL.TheViper                                               NaN
# 3200  GL.TheViper                                               NaN
# 3201  GL.TheViper                                               NaN
#
#       relative_minute
# 3197               19
# 3198               19
# 3199               19
# 3200               19
# ...

# %%
plot_apm(prepare_rec('./data/hera_barles_decider.aoe2record'))
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:78: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(jsonFile)
#     player relative_minute      type  count
# 0  GL.Hera               0     BUILD      5
# 1  GL.Hera               0    DELETE      1
# 2  GL.Hera               0      MOVE     40
# 3  GL.Hera               0     ORDER     16
# 4  GL.Hera               1  DE_QUEUE      7
#   <div id="faa5b82d-287e-4dac-8ed4-aa77b2425ac1" data-root-id="p11217" style="display: contents;"></div>
#        player relative_minute          type  count
# 324  _Barles_               0         BUILD      4
# 325  _Barles_               0      DE_QUEUE      2
# 326  _Barles_               0  GATHER_POINT      5
# 327  _Barles_               0          MOVE     52
# 328  _Barles_               0         ORDER     12
# ...

# %% [markdown]
# twitch link to minute 21 of game:
#
# https://www.twitch.tv/videos/2462173354?t=02h30m25s

# %%
df = rec_to_df('./data/hera_barles_decider.aoe2record')

filtered = df[
    (df['player'] == 'GL.Hera') &
    (df['relative_minute'].astype(float).astype(int) == 21)
]
filtered.head()
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:100: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(jsonFile)
#            type                                            payload   player  \
# 3568     STANCE  {'stance_id': 2, 'object_ids': [3587, 2386, 34...  GL.Hera
# 3569  FORMATION  {'formation_id': 2, 'object_ids': [3587, 2386,...  GL.Hera
# 3571       MOVE  {'object_ids': [249364480, 202440704, 13349683...  GL.Hera
# 3572     STANCE  {'stance_id': 2, 'object_ids': [3587, 2386, 34...  GL.Hera
# 3573     PATROL  {'object_ids': [3587, 2386, 3497, 1830, 4205, ...  GL.Hera
#
#                                      position  relative_minute
# 3568                                      NaN               21
# 3569                                      NaN               21
# ...

# %%
display_full(filtered)
# Out:
# <style type="text/css">
# ...

# %%
plot_apm(prepare_rec('./data/hera_barles_game2.aoe2record'))
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:78: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(jsonFile)
#     player relative_minute          type  count
# 0  GL.Hera               0         BUILD      2
# 1  GL.Hera               0      DE_QUEUE      7
# 2  GL.Hera               0  GATHER_POINT      7
# 3  GL.Hera               0          MOVE     58
# 4  GL.Hera               0         ORDER     14
#   <div id="f9fb9369-c315-444f-a0ba-864af2747faa" data-root-id="p11790" style="display: contents;"></div>
#        player relative_minute          type  count
# 187  _Barles_               0         BUILD      1
# 188  _Barles_               0      DE_QUEUE      7
# 189  _Barles_               0  GATHER_POINT      7
# 190  _Barles_               0          MOVE     40
# 191  _Barles_               0         ORDER     13
# ...

# %% [markdown]
# twitch link to minute 20 of game:
#
# https://www.twitch.tv/videos/2462173354?t=01h13m20s

# %%
df = rec_to_df('./data/hera_barles_game2.aoe2record')

filtered = df[
    (df['player'] == 'GL.Hera') &
    (df['relative_minute'].astype(float).astype(int) == 20)
]
filtered.head()
# Out:
# /Users/luisg/Development/personal/aoe-apm-analysis/utils/aoe_rec.py:100: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(jsonFile)
#            type                                            payload   player  \
# 3932       MOVE  {'object_ids': [330432512, 330891264], 'sequen...  GL.Hera
# 3933  FORMATION  {'formation_id': 2, 'object_ids': [4793, 4809,...  GL.Hera
# 3934  FORMATION  {'formation_id': 2, 'object_ids': [4793, 4809,...  GL.Hera
# 3935     STANCE  {'stance_id': 2, 'object_ids': [4793, 4809, 48...  GL.Hera
# 3936       MOVE  {'object_ids': [330432512, 330891264], 'sequen...  GL.Hera
#
#                                    position  relative_minute
# 3932          {'x': 4.84375, 'y': 68.09375}               20
# 3933                                    NaN               20
# ...

# %%
display_full(filtered)
# Out:
# <style type="text/css">
# ...
